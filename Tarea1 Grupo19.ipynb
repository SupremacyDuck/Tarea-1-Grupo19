# %% [markdown]
# # Tarea 1 Bases de Datos 2022-1 Grupo XX

# %% [markdown]
# ## Integrantes:
# * Vicenzo Brante - 202073014-8
# * Angelo Ibaceta - 202073019-9
# * Ignacio Barahona - 202073040-7

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - ToolKit **sqlalchemy**
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (recuerde actualizar pip3):

# %%
! pip3 install ipython-sql
! pip3 install sqlalchemy
! pip3 install psycopg2

#Use to generate names
! pip3 install names
# Out:
# Requirement already satisfied: ipython-sql in d:\programacion\programas\python\lib\site-packages (0.4.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in d:\programacion\programas\python\lib\site-packages (from ipython-sql) (1.4.35)
# Requirement already satisfied: ipython>=1.0 in d:\programacion\programas\python\lib\site-packages (from ipython-sql) (8.2.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in d:\programacion\programas\python\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: prettytable<1 in d:\programacion\programas\python\lib\site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: six in d:\programacion\programas\python\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlparse in d:\programacion\programas\python\lib\site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: pygments>=2.4.0 in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: matplotlib-inline in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.3)
# Requirement already satisfied: decorator in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: stack-data in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: colorama in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (58.1.0)
# Requirement already satisfied: backcall in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.29)
# Requirement already satisfied: traitlets>=5 in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\programacion\programas\python\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: greenlet!=0.4.17 in d:\programacion\programas\python\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\programacion\programas\python\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in d:\programacion\programas\python\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: executing in d:\programacion\programas\python\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in d:\programacion\programas\python\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in d:\programacion\programas\python\lib\site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Requirement already satisfied: sqlalchemy in d:\programacion\programas\python\lib\site-packages (1.4.35)
# Requirement already satisfied: greenlet!=0.4.17 in d:\programacion\programas\python\lib\site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: psycopg2 in d:\programacion\programas\python\lib\site-packages (2.9.3)
# Requirement already satisfied: names in d:\programacion\programas\python\lib\site-packages (0.3.0)

# %% [markdown]
# ## Importar dependencias

# %%
from datetime import datetime
import random as r
import names
import string

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:nachetox13@localhost:5432/postgres
# Out:
# env: DATABASE_URL=postgresql://postgres:nachetox13@localhost:5432/postgres

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
connection = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='postgres',
   password="nachetox13"
)

print(connection)
cursor = connection.cursor()
# Out:
# <connection object at 0x0000026BD511D140; dsn: 'user=postgres password=xxx dbname=postgres host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "Usuarios"

# %%
# %%sql
# CREATE TABLE "usuarios"(
#     ID_usuario INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     apellido VARCHAR(45),
#     correo VARCHAR(45) NOT NULL,
#     contraseña VARCHAR(50) NOT NULL,
#     fecha_registro TIMESTAMP NOT NULL,
#     PRIMARY KEY (ID_usuario)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ### Tabla "Creadores"

# %%
# %%sql
# CREATE TABLE "creadores"(
#     ID_creador INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     apellido VARCHAR(45) NOT NULL,
#     popularidad INTEGER,
#     Estilo VARCHAR(45),
#     PRIMARY KEY (ID_creador)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ### Tabla "Tipos_NTF"

# %%
# %%sql
# CREATE TABLE "tipos_nft"(
#     ID_tipo INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(20) NOT NULL,
#     PRIMARY KEY (ID_tipo)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ### Tabla "NFT"

# %%
# %%sql
# CREATE TABLE "nft"(
#     ID_nft INTEGER GENERATED ALWAYS AS IDENTITY,
#     nombre VARCHAR(45) NOT NULL,
#     ID_creador INTEGER NOT NULL,
#     id_tipo INTEGER,
#     PRIMARY KEY (ID_nft),
#     FOREIGN KEY (ID_creador) REFERENCES creadores (ID_creador),
#     FOREIGN KEY (id_tipo) REFERENCES tipos_nft (ID_tipo)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ### Tabla "Precio NFT"

# %%
# %%sql
# CREATE TABLE "precio_nft"(
#     ID_nft INTEGER,
#     fecha TIMESTAMP NOT NULL,
#     precio INTEGER NOT NULL,
#     PRIMARY KEY (ID_nft, fecha),
#     FOREIGN KEY (ID_nft) REFERENCES nft (ID_nft)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ### Tabla "Usuario tiene NFT"

# %%
# %%sql
# CREATE TABLE "usuario_tiene_nft"(
#     id_usuario INTEGER,
#     id_nft INTEGER,
#     PRIMARY KEY (id_usuario,id_nft),
#     FOREIGN KEY (id_usuario) REFERENCES usuarios (ID_usuario),
#     FOREIGN KEY (id_nft) REFERENCES nft (ID_nft)
# )
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.
#
# PD: Si el codigo tira error por "violar la unicidad de las PK" es por una coincidencia de numeros random, solamente volver a ejecutar el codigo

# %%
#Recuerde haber ejecutado todas las celdas anteriores!

# Generador de timestamp aleatorio.
def generate_timestamp():
    year = r.randint(2015,2022)
    month = r.randint(1,12)
    day = r.randint(1,31)
    
    hour = r.randint(0,23)
    minute = r.randint(0,59)
    second = r.randint(0,59)
    
    if month in [4, 6, 9, 11] and day > 30:
        day = 30
        
    if month == 2 and day > 28:
        day = 28
        
    return datetime(year, month, day, hour, minute, second)

def generate_password():
    return ''.join(r.choice(string.ascii_uppercase + string.digits) for x in range(15))

print("Borrando Datos Antiguos...")

# Limpia la base de datos.
connection.commit() # En caso de algun error
query = "TRUNCATE TABLE usuarios, creadores, tipos_nft, nft, precio_nft, usuario_tiene_nft RESTART IDENTITY"
cursor.execute(query)
connection.commit()


print("Generando Datos...")

nft_names = ['Crypto Raptors', 'The Binary Girl', 'Sphere Art', 'Fight Punks', 'Thunder NFT', 'Artistic Alpha', 'Digital Unicorns', 'Bling Bits', 'Secret Stones', 'Crypto Potato', 'Futuristic Realism', 'Nova Auroras', 'Dreamy Imaginations', 'Reflected Light', 'Spells of Genesis', 'Crypto Felines', 'Dose of Art', 'To The Moon', 'Artful Antlers', 
'Butterfly Dust', 'Depressed Dragons', 'Crypto Diamonds', 'Healthy Hedgehogs', 'Crypto Jackpot', 'Minecraft Sphere', 'Crypto Boom', 'Lucky Lizards', 'Rockin Crypto', 'Crystalline Canyon', 'Koala Kickers', 'Clumsy Crocodiles', 'Mountain of Clouds', 'Blizz Blizzard', 'Cryptokitty Ville', 'Cryptonaut', 'Mike Halloween Yodelers', 'The Teacup Pomeranian', 
'Art Dodger', 'Awesome Concept', 'Aliens Abduction', 'Animated Hard Art', 'Ultimate Iconic Crypto (IUC)', 'Hilarious Horses', '1-Love', '0NOZER0', 'Meteorite NFT', 'Bee Token', 'Elephant Treasure Hunt', 'Crypto Life', '1NiTRO', 'Dust Rift', 'Tokenized Superheroes', 'Techno Abstract Aesthetics', 'Digi Gods', 'Outstanding Octopus', 'Panther NFT', 
'Cypherpunk Samurai', 'Rich Rhinos', 'Crypto Punked', 'Funny Frogs', 'Bit NFT', 'Phonetic Phoenix', 'Flame Stinger', 'Fight For The Title', 'Koalas in Love', 'Touchdown', 'Resilient Rats', 'Bloom of Flowers', 'NFT Lord', 'Fair Coin', 'Art Rumble', 'Light Embrace', 'Crypto Bunny Ranch', 'Crypto Pigeon Race', 'Water Wiggle', 'Wowoo World', 
'Crypto Club', 'Crypto Kitties Of War', 'Visionary Crypto', 'Women Power', 'Rainbows Ends', 'Cards of Polo', 'Crypto Kitties', 'Busy Bats', '0xHile', 'Token Watchdogs', 'Non Fungible Nibbles', 'Pandamonium', '3D Me', 'Midas NFTs', 'Graceful Gorillas', 'United Crypto Token (UCT)', 'Crypto Art Gallery', 'Dark Horse Lady', 'Block View', 'Arty Arts', 
'White Storm', 'Krypto Queen', 'Clever Chimp', 'Qat Tree Unicorn', 'Anna Frozen Entertainers', 'Artificial Rocks', '0NOCH0', 'Flame Blade', 'The Gold Betta', 'Doge Pal', 'Elite Fur Dog Race Club', 'Dust Sifter', 'Moonlit Butterfly', 'Art Lover Box', 'Madame Witch', 'Fantasy Token', 'Bitsy', 'Hive City', 'Couch Potato', 'Burger Bits', 'Crypto Potluck', 
'Cyberboxer', 'Calm Crows', 'Crumbs NFT', 'Mint Chocolates', 'Atollon Coral', 'Dapper Dinos', 'Flame Cats', 'Addictive Animals', 'Alice Wonderland Frozen Carolers', 'Coin Dance', 'Giant Coin', 'Silver Lining Pixy', 'Headed Shark Attack', 'Ultimate League Of Paragon', 'Darker Clouds', 'Blue Mood Chip', 'Brush Point', 'Enthusiastic Elephants', 'Ultra Cool Dogs', 
'Pink Sports Cars']

dominios = ["hola.cl", "google.com","usm.cl","prestigio.usm.cl","crypto.co","basededatos.top"]

tipos_nft = [
    ("Imagen",), ("Musica",),("Juegos",), ("Modelo 3D",), ("Pixel",), ("Membresia",),("Arte",),
]

estilos = [
    ("Anime",),("Manga",),("Arte Retro",),("Arte Moderno",),("Impresionismo",),("Barroco",),("Arte Antiguo",),("Arte 3D",),("Paisaje",)
]

n_usuarios = 200
n_creadores = 20
n_nft = len(nft_names)
n_tipos_nft = len(tipos_nft)
n_usuario_tiene_nft = 80

usuarios = []
for _ in range(1, n_usuarios+1):
    nombre = names.get_first_name()
    apellido = names.get_last_name()
    correo = nombre.lower()+"."+apellido[:4].lower()+"@"+r.choice(dominios)
    usuarios.append((nombre,apellido,correo,generate_password(),generate_timestamp()))

creadores = [(names.get_first_name(), names.get_last_name(), r.randint(0,5), r.choice(estilos)) for _ in range(1,n_creadores+1)]

nft = [(nft_names[n], r.randint(1,n_creadores), r.randint(1,n_tipos_nft)) for n in range(n_nft)]

precio_nft = [(r.randint(1,n_nft), generate_timestamp(), r.randint(500, 100000)) for _ in range(300)]

usuario_tiene_nft = [(r.randint(1,n_usuarios),r.randint(1,n_nft)) for _ in range(81)]


insert = [
    "INSERT INTO usuarios (nombre, apellido, correo, contraseña, fecha_registro) VALUES (%s, %s, %s, %s, %s)",
    "INSERT INTO creadores (nombre, apellido, popularidad, estilo) VALUES (%s, %s, %s, %s)",
    "INSERT INTO tipos_nft (nombre) VALUES (%s)",
    "INSERT INTO nft (nombre, id_creador, id_tipo) VALUES (%s, %s, %s)",
    "INSERT INTO precio_nft (id_nft, fecha, precio) VALUES (%s, %s, %s)",
    "INSERT INTO usuario_tiene_nft (id_usuario, id_nft) VALUES (%s, %s)"
]


for usuario in usuarios:
    cursor.execute(insert[0], usuario)

for creador in creadores:
    cursor.execute(insert[1], creador) 

for tipo in tipos_nft:
    cursor.execute(insert[2], tipo)  

for n in nft:
    cursor.execute(insert[3], n)  
    
for precio in precio_nft:
    cursor.execute(insert[4], precio) 
    
for usr in usuario_tiene_nft:
    cursor.execute(insert[5], usr)
    
connection.commit()

print("Todo Listo!")
# Out:
# Borrando Datos Antiguos...
# Generando Datos...
# Todo Listo!

# %% [markdown]
# ## Consultas
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1
# **ID y Nombre del creador de un estilo X con mayor popularidad.**
# ###### Si hay más de uno, ponga solamente el primero
#
# Ejemplo:
#
# |Id |  Creador      |
# |---|-----------|
# | 12 |Levi Ackerman |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT id_creador AS "Id", CONCAT(nombre,' ',apellido) AS "Creador"
# FROM creadores
# ORDER BY popularidad DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(1, 'Joseph Mcdonald')]

# %% [markdown]
# ### Consulta 2
# **Cantidad de precios que ha tenido históricamente cada NTF.**
#
# Ejemplo:
#
#
# | NFT     | Cantidad de precios |
# |--------------|----------|
# | Minecraft Sphere |    3     |
# | The Binary Girl     |    7     |
# | ...          |   ...    |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nft.nombre AS "NFT", COUNT(precio_nft.id_nft) AS "Cantidad de precios"
# FROM nft
# INNER JOIN precio_nft
# USING (id_nft)
# GROUP BY (nft.nombre);
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 119 rows affected.
# [('Spells of Genesis', 1),
#  ('Dose of Art', 3),
#  ('Art Rumble', 2),
#  ('Aliens Abduction', 3),
#  ('Meteorite NFT', 1),
#  ('Atollon Coral', 3),
#  ('Bling Bits', 3),
#  ('Depressed Dragons', 2),
#  ('Artificial Rocks', 3),
#  ('Crypto Jackpot', 4),
#  ('Light Embrace', 2),
#  ('Crypto Kitties Of War', 1),
#  ('Pink Sports Cars', 3),
#  ('Cards of Polo', 2),
#  ('Addictive Animals', 1),
#  ('Visionary Crypto', 2),
#  ('Animated Hard Art', 6),
#  ('Lucky Lizards', 3),
#  ('Bloom of Flowers', 1),
#  ('Flame Stinger', 5),
#  ('The Gold Betta', 3),
#  ('Art Lover Box', 2),
#  ('Doge Pal', 3),
#  ('Darker Clouds', 1),
#  ('Digital Unicorns', 1),
#  ('Digi Gods', 2),
#  ('Token Watchdogs', 1),
#  ('Futuristic Realism', 4),
#  ('0NOCH0', 2),
#  ('Wowoo World', 1),
#  ('Crypto Felines', 3),
#  ('Hilarious Horses', 3),
#  ('Ultra Cool Dogs', 2),
#  ('Crypto Pigeon Race', 3),
#  ('Rainbows Ends', 2),
#  ('Tokenized Superheroes', 1),
#  ('Alice Wonderland Frozen Carolers', 3),
#  ('Anna Frozen Entertainers', 3),
#  ('Rich Rhinos', 2),
#  ('Secret Stones', 1),
#  ('Crypto Club', 1),
#  ('Crumbs NFT', 2),
#  ('Elite Fur Dog Race Club', 3),
#  ('Crypto Art Gallery', 1),
#  ('Couch Potato', 4),
#  ('Panther NFT', 5),
#  ('Hive City', 3),
#  ('Moonlit Butterfly', 3),
#  ('Cryptokitty Ville', 2),
#  ('Bee Token', 3),
#  ('Reflected Light', 2),
#  ('Outstanding Octopus', 2),
#  ('Healthy Hedgehogs', 2),
#  ('Crypto Potluck', 6),
#  ('Thunder NFT', 2),
#  ('Techno Abstract Aesthetics', 2),
#  ('Dust Rift', 2),
#  ('Giant Coin', 3),
#  ('Women Power', 3),
#  ('Touchdown', 1),
#  ('Midas NFTs', 1),
#  ('Funny Frogs', 3),
#  ('Calm Crows', 5),
#  ('Dark Horse Lady', 3),
#  ('Crypto Punked', 4),
#  ('Dreamy Imaginations', 4),
#  ('Madame Witch', 6),
#  ('Busy Bats', 4),
#  ('Blizz Blizzard', 3),
#  ('Crypto Raptors', 2),
#  ('Crypto Boom', 2),
#  ('1NiTRO', 2),
#  ('Krypto Queen', 5),
#  ('Graceful Gorillas', 1),
#  ('To The Moon', 3),
#  ('Qat Tree Unicorn', 1),
#  ('NFT Lord', 1),
#  ('Fight Punks', 2),
#  ('Mike Halloween Yodelers', 2),
#  ('Koalas in Love', 2),
#  ('Cyberboxer', 2),
#  ('Art Dodger', 2),
#  ('Fair Coin', 5),
#  ('0NOZER0', 2),
#  ('Sphere Art', 2),
#  ('White Storm', 4),
#  ('Burger Bits', 3),
#  ('The Binary Girl', 1),
#  ('Flame Blade', 1),
#  ('The Teacup Pomeranian', 2),
#  ('Non Fungible Nibbles', 1),
#  ('Fantasy Token', 1),
#  ('Ultimate League Of Paragon', 1),
#  ('Awesome Concept', 2),
#  ('Crypto Potato', 1),
#  ('Crypto Bunny Ranch', 3),
#  ('Nova Auroras', 3),
#  ('3D Me', 2),
#  ('Fight For The Title', 1),
#  ('Phonetic Phoenix', 2),
#  ('Rockin Crypto', 3),
#  ('Clumsy Crocodiles', 3),
#  ('Headed Shark Attack', 3),
#  ('Butterfly Dust', 1),
#  ('Crypto Kitties', 5),
#  ('Silver Lining Pixy', 4),
#  ('Arty Arts', 4),
#  ('Clever Chimp', 2),
#  ('Water Wiggle', 3),
#  ('Blue Mood Chip', 3),
#  ('Coin Dance', 4),
#  ('Resilient Rats', 3),
#  ('Artful Antlers', 2),
#  ('Elephant Treasure Hunt', 2),
#  ('0xHile', 2),
#  ('Block View', 2),
#  ('Ultimate Iconic Crypto (IUC)', 7),
#  ('Bitsy', 1),
#  ('Bit NFT', 3)]

# %% [markdown]
# ### Consulta 3
# **El nombre y tipo (nombre del tipo) del NFT históricamente más caro.**
# ###### Si hay más de uno, ponga solamente el primero
# Ejemplo:
#
# | NFT    | Tipo |
# |----------------|--------|
# | Minecraft Sphere| Arte 3D |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 0 rows affected.
# []

# %% [markdown]
# ### Consulta 4
# **Nombre y apellido del usuario con más número de NFTs.**
#
# Ejemplo:
#
# | Nombre     | Apellido |
# |----------------|--------|
# | Levi | Ackerman |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';

# %% [markdown]
# ### Consulta 5
# **El NFT que más veces cambió de precio historicamente.**
#
# Ejemplo:
#
# |  ID  | NFT |
# |--------|-------|
# | 11 |Minecraft Sphere |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';

# %% [markdown]
# ### Consulta 6
# **Usuarios que NO tienen un NFT.**
#
# Ejemplo
#
# |Nombre | Apellido|
# |--------|-------|
# |Guillermo    | Diaz |
# |Markus | Person |
# |Rick   | Astley |
# |... | ...|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre AS "Nombre", apellido AS "Apellido"
#   FROM usuarios
#  WHERE id_usuario NOT IN (SELECT id_usuario
#                        FROM usuario_tiene_nft)
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 132 rows affected.
# [('Gary', 'Poyner'),
#  ('Ronald', 'Britt'),
#  ('Paul', 'Mattingly'),
#  ('Jessica', 'Wright'),
#  ('James', 'Bennett'),
#  ('Ricardo', 'Leger'),
#  ('Colette', 'Davis'),
#  ('Pat', 'Townsend'),
#  ('Noel', 'Troyer'),
#  ('Nancy', 'Smith'),
#  ('Marilyn', 'Gingras'),
#  ('William', 'Bledsoe'),
#  ('William', 'Shilt'),
#  ('Diana', 'Reynolds'),
#  ('Steven', 'Darling'),
#  ('Carole', 'Scroggin'),
#  ('Myrna', 'Aaron'),
#  ('Alton', 'Deal'),
#  ('Jasmine', 'Lewis'),
#  ('Joseph', 'Ogden'),
#  ('Duane', 'Juul'),
#  ('Matthew', 'Perry'),
#  ('David', 'Dotson'),
#  ('Jessica', 'Rast'),
#  ('William', 'Quilliams'),
#  ('Robin', 'Neer'),
#  ('Dollie', 'Whitaker'),
#  ('Elizabeth', 'Ford'),
#  ('Sandra', 'Geisler'),
#  ('Phillip', 'Cannellos'),
#  ('Olga', 'Fowler'),
#  ('Brandi', 'Rosenbaum'),
#  ('David', 'Tomasek'),
#  ('Kimberly', 'Vanderploeg'),
#  ('Michael', 'Crenshaw'),
#  ('James', 'Kessler'),
#  ('Arlene', 'Bernard'),
#  ('Elvira', 'Noble'),
#  ('David', 'Rawls'),
#  ('Gilbert', 'Seifert'),
#  ('Mark', 'Russell'),
#  ('Germaine', 'Hatfield'),
#  ('Phyllis', 'Wiggins'),
#  ('Michael', 'Pettit'),
#  ('Donna', 'Driever'),
#  ('Charles', 'Foley'),
#  ('David', 'Stiles'),
#  ('Erika', 'Baumgartner'),
#  ('Luis', 'Williams'),
#  ('Amanda', 'Goleman'),
#  ('Lamar', 'Hendriks'),
#  ('Tricia', 'Rice'),
#  ('Corey', 'Decker'),
#  ('Alison', 'Donner'),
#  ('Laura', 'Williams'),
#  ('Barbara', 'Parker'),
#  ('Linda', 'Davis'),
#  ('Donald', 'Lydick'),
#  ('Daniel', 'Thomas'),
#  ('Rita', 'Ledesma'),
#  ('Lisa', 'Burns'),
#  ('Erwin', 'Coleman'),
#  ('Rhonda', 'George'),
#  ('Danial', 'Symonds'),
#  ('Michael', 'Rountree'),
#  ('Donna', 'Clawson'),
#  ('Richard', 'Benson'),
#  ('Delta', 'Coleman'),
#  ('Melvin', 'Ballard'),
#  ('Ericka', 'Fried'),
#  ('Nora', 'Hammond'),
#  ('Kami', 'Shick'),
#  ('Linda', 'Schlichter'),
#  ('Herbert', 'Page'),
#  ('Jodie', 'Collins'),
#  ('Karl', 'Patterson'),
#  ('Cedric', 'Fernandez'),
#  ('Catherine', 'Berry'),
#  ('Kristal', 'Castle'),
#  ('Beth', 'Gilliss'),
#  ('Dennis', 'Bledsoe'),
#  ('Faith', 'Burns'),
#  ('Kathleen', 'Martinez'),
#  ('Cecil', 'Paul'),
#  ('Eddie', 'Marti'),
#  ('Jessica', 'Fox'),
#  ('Harry', 'Peters'),
#  ('Barry', 'Johnson'),
#  ('David', 'Miller'),
#  ('Gloria', 'Redding'),
#  ('Charlotte', 'Pierce'),
#  ('Daniel', 'Lamb'),
#  ('Cheryl', 'Maheu'),
#  ('Sandra', 'Witkowski'),
#  ('James', 'Penalosa'),
#  ('Cameron', 'Enriquez'),
#  ('Andrea', 'Mcardle'),
#  ('Timothy', 'Rickett'),
#  ('Juan', 'Gabriele'),
#  ('Antonio', 'Schofield'),
#  ('Barry', 'Mock'),
#  ('Harold', 'Sublett'),
#  ('Jerome', 'Dingee'),
#  ('John', 'Lopez'),
#  ('Therese', 'Legette'),
#  ('Kerstin', 'Ramirez'),
#  ('Joyce', 'Breeding'),
#  ('Melanie', 'Johnson'),
#  ('William', 'Casey'),
#  ('Jessica', 'Freitag'),
#  ('Frances', 'Mcalister'),
#  ('Manuel', 'Albus'),
#  ('Hana', 'Wilmoth'),
#  ('Mary', 'Ellis'),
#  ('Shauna', 'Thompson'),
#  ('Jerry', 'Rodriguez'),
#  ('Myrna', 'Miller'),
#  ('Richard', 'Dineen'),
#  ('Edward', 'Jackson'),
#  ('Marcos', 'Miller'),
#  ('Shelia', 'Escamilla'),
#  ('Robert', 'Ratliff'),
#  ('Bobbie', 'Smith'),
#  ('Michael', 'Boyce'),
#  ('David', 'Patterson'),
#  ('Alice', 'Perry'),
#  ('Angel', 'Cunningham'),
#  ('Jeffrey', 'Gill'),
#  ('John', 'Trowery'),
#  ('David', 'Williams'),
#  ('Patricia', 'Gallagher'),
#  ('Wallace', 'Brunelle')]

# %% [markdown]
# ### Consulta 7
# **Top 4 NFTs más caros actualmente de un id_tipo X .**
#
# Ejemplo:
#
# |NFT |
# |--------|
# |Minecraft Sphere |
# |The Binary Girl |
# |Koalas in Love |
# |Art Dodger |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nft.nombre AS "NFT"
# FROM nft
# RIGHT JOIN precio_nft
# USING (id_nft)
# WHERE nft.id_tipo = 5 --Tipo
#     ORDER BY precio DESC
#     LIMIT 4
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 4 rows affected.
# [('Calm Crows',),
#  ('Addictive Animals',),
#  ('Bee Token',),
#  ('Anna Frozen Entertainers',)]

# %% [markdown]
# ### Consulta 8
# **Los precios de todos los NFTs entre los años 2017 y 2019 inclusive.**
#
# Ejemplo:
#
# |NFT |Precio |
# |----|---|
# |Minecraft Sphere |  4000 |
# |The Binary Girl | 3000|
# | Koalas in Love | 6000 |
# |Minecraft Sphere |  1250 |
# | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT nombre AS "NFT", precio AS "PRECIO"
# FROM nft
#
#
#
# ;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 137 rows affected.
# [('Crypto Raptors', 1),
#  ('The Binary Girl', 2),
#  ('Sphere Art', 3),
#  ('Fight Punks', 4),
#  ('Thunder NFT', 5),
#  ('Artistic Alpha', 6),
#  ('Digital Unicorns', 7),
#  ('Bling Bits', 8),
#  ('Secret Stones', 9),
#  ('Crypto Potato', 10),
#  ('Futuristic Realism', 11),
#  ('Nova Auroras', 12),
#  ('Dreamy Imaginations', 13),
#  ('Reflected Light', 14),
#  ('Spells of Genesis', 15),
#  ('Crypto Felines', 16),
#  ('Dose of Art', 17),
#  ('To The Moon', 18),
#  ('Artful Antlers', 19),
#  ('Butterfly Dust', 20),
#  ('Depressed Dragons', 21),
#  ('Crypto Diamonds', 22),
#  ('Healthy Hedgehogs', 23),
#  ('Crypto Jackpot', 24),
#  ('Minecraft Sphere', 25),
#  ('Crypto Boom', 26),
#  ('Lucky Lizards', 27),
#  ('Rockin Crypto', 28),
#  ('Crystalline Canyon', 29),
#  ('Koala Kickers', 30),
#  ('Clumsy Crocodiles', 31),
#  ('Mountain of Clouds', 32),
#  ('Blizz Blizzard', 33),
#  ('Cryptokitty Ville', 34),
#  ('Cryptonaut', 35),
#  ('Mike Halloween Yodelers', 36),
#  ('The Teacup Pomeranian', 37),
#  ('Art Dodger', 38),
#  ('Awesome Concept', 39),
#  ('Aliens Abduction', 40),
#  ('Animated Hard Art', 41),
#  ('Ultimate Iconic Crypto (IUC)', 42),
#  ('Hilarious Horses', 43),
#  ('1-Love', 44),
#  ('0NOZER0', 45),
#  ('Meteorite NFT', 46),
#  ('Bee Token', 47),
#  ('Elephant Treasure Hunt', 48),
#  ('Crypto Life', 49),
#  ('1NiTRO', 50),
#  ('Dust Rift', 51),
#  ('Tokenized Superheroes', 52),
#  ('Techno Abstract Aesthetics', 53),
#  ('Digi Gods', 54),
#  ('Outstanding Octopus', 55),
#  ('Panther NFT', 56),
#  ('Cypherpunk Samurai', 57),
#  ('Rich Rhinos', 58),
#  ('Crypto Punked', 59),
#  ('Funny Frogs', 60),
#  ('Bit NFT', 61),
#  ('Phonetic Phoenix', 62),
#  ('Flame Stinger', 63),
#  ('Fight For The Title', 64),
#  ('Koalas in Love', 65),
#  ('Touchdown', 66),
#  ('Resilient Rats', 67),
#  ('Bloom of Flowers', 68),
#  ('NFT Lord', 69),
#  ('Fair Coin', 70),
#  ('Art Rumble', 71),
#  ('Light Embrace', 72),
#  ('Crypto Bunny Ranch', 73),
#  ('Crypto Pigeon Race', 74),
#  ('Water Wiggle', 75),
#  ('Wowoo World', 76),
#  ('Crypto Club', 77),
#  ('Crypto Kitties Of War', 78),
#  ('Visionary Crypto', 79),
#  ('Women Power', 80),
#  ('Rainbows Ends', 81),
#  ('Cards of Polo', 82),
#  ('Crypto Kitties', 83),
#  ('Busy Bats', 84),
#  ('0xHile', 85),
#  ('Token Watchdogs', 86),
#  ('Non Fungible Nibbles', 87),
#  ('Pandamonium', 88),
#  ('3D Me', 89),
#  ('Midas NFTs', 90),
#  ('Graceful Gorillas', 91),
#  ('United Crypto Token (UCT)', 92),
#  ('Crypto Art Gallery', 93),
#  ('Dark Horse Lady', 94),
#  ('Block View', 95),
#  ('Arty Arts', 96),
#  ('White Storm', 97),
#  ('Krypto Queen', 98),
#  ('Clever Chimp', 99),
#  ('Qat Tree Unicorn', 100),
#  ('Anna Frozen Entertainers', 101),
#  ('Artificial Rocks', 102),
#  ('0NOCH0', 103),
#  ('Flame Blade', 104),
#  ('The Gold Betta', 105),
#  ('Doge Pal', 106),
#  ('Elite Fur Dog Race Club', 107),
#  ('Dust Sifter', 108),
#  ('Moonlit Butterfly', 109),
#  ('Art Lover Box', 110),
#  ('Madame Witch', 111),
#  ('Fantasy Token', 112),
#  ('Bitsy', 113),
#  ('Hive City', 114),
#  ('Couch Potato', 115),
#  ('Burger Bits', 116),
#  ('Crypto Potluck', 117),
#  ('Cyberboxer', 118),
#  ('Calm Crows', 119),
#  ('Crumbs NFT', 120),
#  ('Mint Chocolates', 121),
#  ('Atollon Coral', 122),
#  ('Dapper Dinos', 123),
#  ('Flame Cats', 124),
#  ('Addictive Animals', 125),
#  ('Alice Wonderland Frozen Carolers', 126),
#  ('Coin Dance', 127),
#  ('Giant Coin', 128),
#  ('Silver Lining Pixy', 129),
#  ('Headed Shark Attack', 130),
#  ('Ultimate League Of Paragon', 131),
#  ('Darker Clouds', 132),
#  ('Blue Mood Chip', 133),
#  ('Brush Point', 134),
#  ('Enthusiastic Elephants', 135),
#  ('Ultra Cool Dogs', 136),
#  ('Pink Sports Cars', 137)]

# %% [markdown]
# ### Consulta 9
# **Creador al cual le han comprado más NFTs.**
#
# Ejemplo:
#
# |Nombre |Apellido |Cantidad |
# |-|--|-----|
# | Levi |Ackerman |32|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';

# %% [markdown]
# ### Consulta 10
# **El NFT con mayor precio actual, que pertenezca a un creador X.**
#
# Ejemplo:
#
# |NFT |Valor|
# |-|-------|
# |Minecraft Sphere |18000|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';

# %% [markdown]
# ### Consulta BONUS
# ###### (Vale por un abrazo psicológico)
#
# **El usuario que posee más dinero en NFTs considerando los precios actuales de estos**
#
# Ejemplo:
#
# |Usuario |Dinero|
# |-|-------|
# |Levi Ackerman |8000001|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
# SELECT
#     *
# FROM
#     Creadores
# WHERE
#     nombre = 'WillyRex';
